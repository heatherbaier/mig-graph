# %%
import geopandas as gpd
from shapely import wkt
import pandas as pd

# %%
flows = pd.read_csv("./good_data/flows_gdf.csv")
flows["origin_coords"] = "POINT" + flows["origin_coords"].str.replace(", ", " ")
# flows = flows[flows["crsyr1"] != 9999]
# flows = flows.dropna(subset = ['geometry'])
# flows['origin_coords'] = flows['origin_coords'].apply(wkt.loads)
# flows = gpd.GeoDataFrame(flows, geometry='origin_coords')
print(flows.shape)
flows.head()
# Out:
# (5327, 17)
#    Unnamed: 0  Unnamed: 0.1  crsyr1  origin_loc  \
# 0           0             0    1972  Guanajuato
# 1           1             1    1980  Guanajuato
# 2           2             2    1978  Guanajuato
# 3           3             3    1980  Guanajuato
# 4           4             4    1975  Guanajuato
#
#                             cross_loc                           us_loc  \
# 0  Tijuana, Baja California del Norte                 Chicago, IL PMSA
# 1  Tijuana, Baja California del Norte                San Diego, CA MSA
# 2  Tijuana, Baja California del Norte  Los Angeles-Long Beach, CA PMSA
# 3  Tijuana, Baja California del Norte                San Jose, CA PMSA
# 4            Nuevo Laredo, Tamaulipas                 Chicago, IL PMSA
#
#                  cross_loc_coords             origin_coords  \
# 0  POINT(-116.964662, 32.5010188)  POINT(-101.0 20.9876996)
# 1  POINT(-116.964662, 32.5010188)  POINT(-101.0 20.9876996)
# ...

# %%
# flows.to_file("./origin_shp/origin_shp.shp")

# %%
flows[flows["origin_coords"].str.contains("11.0480288")]
# Out:
#       Unnamed: 0  Unnamed: 0.1  crsyr1 origin_loc  \
# 116          116           116    1988        NaN
# 243          243           243    1985        NaN
# 282          282           282    1985        NaN
# 287          287           287    1978        NaN
# 294          294           294    1976        NaN
# ...          ...           ...     ...        ...
# 4536        4536          4536    2001        NaN
# 4567        4567          4567    1979        NaN
# 4580        4580          4580    1994        NaN
# 4756        4756          4756    2000        NaN
# 4759        4759          4759    2001        NaN
#
#                                cross_loc                             us_loc  \
# 116   Tijuana, Baja California del Norte  Riverside-San Bernardino, CA PMSA
# 243   Tijuana, Baja California del Norte    Los Angeles-Long Beach, CA PMSA
# 282   Tijuana, Baja California del Norte                     Fresno, CA MSA
# ...

# %%
flows[flows["crsyr1"] > 1972]
# Out:
#       Unnamed: 0  Unnamed: 0.1  crsyr1  origin_loc  \
# 1              1             1    1980  Guanajuato
# 2              2             2    1978  Guanajuato
# 3              3             3    1980  Guanajuato
# 4              4             4    1975  Guanajuato
# 6              6             6    1978  Guanajuato
# ...          ...           ...     ...         ...
# 5322        5322          5322    2004      Oaxaca
# 5323        5323          5323    2016      Oaxaca
# 5324        5324          5324    1985      Oaxaca
# 5325        5325          5325    1994      Oaxaca
# 5326        5326          5326    1982      Oaxaca
#
#                                cross_loc                           us_loc  \
# 1     Tijuana, Baja California del Norte                San Diego, CA MSA
# 2     Tijuana, Baja California del Norte  Los Angeles-Long Beach, CA PMSA
# 3     Tijuana, Baja California del Norte                San Jose, CA PMSA
# ...

# %%
len(flows['origin_loc'].unique())
# Out:
# 285

# %%
sorted(flows['crsyr1'].unique())
# Out:
# [1921,
#  1924,
#  1928,
#  1935,
#  1937,
#  1938,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018]

# %%
flows['crsyr1'].value_counts().head(50)
# Out:
# 1986    197
# 1979    194
# 1980    194
# 1985    190
# 1988    186
# 1989    176
# 1990    169
# 1975    154
# 1978    153
# 1984    146
# 1973    136
# 1982    135
# 1976    135
# 1995    134
# 1977    128
# 1991    123
# 1983    122
# 1987    119
# 1981    118
# 1972    117
# 1993    113
# 2000    109
# 1974    107
# 1970    105
# 1998    104
# 1997    101
# 1996     99
# 1994     99
# 1992     96
# 1999     92
# 1969     78
# 1971     71
# 1968     61
# 2001     59
# 2002     51
# 1967     51
# 1965     50
# 2003     48
# 2004     38
# 1966     38
# 2005     37
# 1964     29
# 1960     23
# 2007     23
# 1952     21
# 1950     21
# 2006     20
# 1962     20
# 1951     18
# 1963     18
# Name: crsyr1, dtype: int64

# %%
flows['cross_loc'].value_counts()
# Out:
# Tijuana, Baja California del Norte       3046
# Juárez, Chihuahua                         365
# Nuevo Laredo, Tamaulipas                  269
# Mexicali, Baja California del Norte       266
# Nogales, Sonora                           206
# Agua Prieta, Sonora                       189
# Piedras Negras, Coahuila de Zaragoza      151
# Matamoros, Tamaulipas                     133
# Reynosa, Tamaulipas                        94
# , Coahuila de Zaragoza                     84
# Tecate, Baja California del Norte          64
# San Luis Río Colorado, Sonora              46
# General Plutarco Elías Calles, Sonora      36
# Altar, Sonora                              34
# Ojinaga, Chihuahua                         16
# Ascención, Chihuahua                       11
# Miguel Alemán, Tamaulipas                  11
# Río Bravo, Tamaulipas                       8
# Naco, Sonora                                6
# Monterrey, Nuevo León                       4
# ...
